# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import numpy as np
from numpy.fft import *
#Exercice 1

f = 10  # Frequency, in cycles per second, or Hertz
f_s = 50  # Sampling rate, or number of measurements per second
t = np.linspace(0, 1, 2 * f_s, endpoint=False)
pure = np.sin(f * 2 * np.pi * t)+np.cos(f* 2*np.pi*t)


#Exercice 2
plt.plot(t,pure)
plt.title('Periodic signal')
plt.ylabel('Signal amplitude')
plt.xlabel('Time[s]')
plt.show()

A = np.fft.fft(pure)
plt.plot(np.real(A))
plt.show()

#Exercice 3


noise = np.random.normal(0, 1, pure.shape)
signal_noise = pure+ noise

plt.plot(t,signal_noise)
plt.title('Periodic signal with noise')
plt.ylabel('Signal amplitude')
plt.xlabel('Time[s]')
plt.show()

B = np.fft.fft(signal_noise)
plt.plot(np.real(B))
plt.show()

#Exercice 4
values_original = x.reshape((len(pure), 1))
scaler=StandardScaler()
data_standard=scaler.fit_transform(values)

plt.plot(t,data_standard)
plt.title('Periodic signal normalized')
plt.ylabel('Signal amplitude')
plt.xlabel('Time[s]')
plt.show()

values_noise = signal_noise.reshape((len(signal_noise), 1))
scaler=StandardScaler()
data_standard_noise=scaler.fit_transform(values_noise)

plt.plot(t,data_standard_noise)
plt.title('Periodic signal with noise normalized')
plt.ylabel('Signal amplitude')
plt.xlabel('Time[s]')
plt.show()
